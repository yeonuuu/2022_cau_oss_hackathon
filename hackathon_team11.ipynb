# %% [markdown]
# <a href="https://colab.research.google.com/github/yeonuuu/2022_cau_oss_hackathon/blob/main/hackathon_team11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임 -> 런타임 연결 해제 및 삭제"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
#  *    "런타임 -> 런타임 다시시작"은 클라우드 스토리지에 저장된 모델은 유지됨
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2022_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드가 적발될 경우
# *  Pre-trained 모델을 사용한 경우 (transfer learning 포함)
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

from tensorflow import keras
from keras.utils import np_utils
from keras import datasets, layers, models

# 데이터셋 로드 (MNIST, fashion-MNIST, Kujushiji-MNIST, MNIST_corrupted (test only))
train_ds, test_ds = tfds.load('mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)

train_ds2, test_ds2 = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds2['label'] += 10;
test_ds2['label'] += 10;

train_ds3, test_ds3 = tfds.load('kmnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds3['label'] += 20;
test_ds3['label'] += 20;

test_ds4 = tfds.load('mnist_corrupted/zigzag', split='test', shuffle_files=False, batch_size=-1)

# 데이터셋 병합 (training: 180,000개, test: 40,000개)
x_train = np.append(np.append(train_ds['image'], train_ds2['image'], 0), train_ds3['image'], 0);
y_train = np.append(np.append(train_ds['label'], train_ds2['label'], 0), train_ds3['label'], 0);

x_test = np.append(np.append(np.append(test_ds['image'], test_ds2['image'], 0), test_ds3['image'], 0), test_ds4['image'], 0);
y_test = np.append(np.append(np.append(test_ds['label'], test_ds2['label'], 0), test_ds3['label'], 0), test_ds4['label'], 0);

# 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 총 클래스 개수: 30, 입력 데이터 구조: (28, 28, 1)
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
print(num_classes, input_shape)
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to ~/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to ~/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to ~/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incomplete9VUPGN/fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incomplete9VUPGN/fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to ~/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteUPEOHD/kmnist-train.tfrecord*...:   0%|          | 0/60…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteUPEOHD/kmnist-test.tfrecord*...:   0%|          | 0/100…
# Dataset kmnist downloaded and prepared to ~/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 235.23 MiB (download: 235.23 MiB, generated: Unknown size, total: 235.23 MiB) to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incomplete4OMZFZ/mnist_corrupted-train.tfrecord*.…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incomplete4OMZFZ/mnist_corrupted-test.tfrecord*..…
# Dataset mnist_corrupted downloaded and prepared to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0. Subsequent calls will reuse this data.
# 30 (28, 28, 1)

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test_after를 변경하지 말 것
x_train_after = x_train.reshape([-1, 28, 28, 1]) / 255
x_test_after = x_test.reshape([-1, 28, 28, 1]) / 255

# %%
# Out:
# 180000

# %% [markdown]
# # **3. 모델 생성**

# %%
# 순차 모델 생성 (가장 기본구조)
model = keras.Sequential()

model.add(keras.layers.Conv2D(32, (3,3), activation = 'relu', input_shape=(28,28,1)))
model.add(keras.layers.MaxPooling2D(2,2))
model.add(keras.layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(keras.layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(keras.layers.MaxPooling2D(2,2))
model.add(keras.layers.Conv2D(128, (3,3), activation = 'relu'))
model.add(keras.layers.MaxPooling2D(2,2))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(30, activation='softmax'))

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표

model.compile(optimizer = 'adam',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')
print(len(x_train_after))
# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 32, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test_after, y_test))

#model.summary()
# Out:
# 180000
# Epoch 1/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.5247 - accuracy: 0.8338
# Epoch 1: val_accuracy improved from -inf to 0.85027, saving model to /content/checkpoint_entire_best.h5
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.5247 - accuracy: 0.8338 - val_loss: 0.5938 - val_accuracy: 0.8503
# Epoch 2/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.2305 - accuracy: 0.9250
# Epoch 2: val_accuracy improved from 0.85027 to 0.88065, saving model to /content/checkpoint_entire_best.h5
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.2305 - accuracy: 0.9250 - val_loss: 0.4522 - val_accuracy: 0.8806
# Epoch 3/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1839 - accuracy: 0.9399
# Epoch 3: val_accuracy did not improve from 0.88065
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1840 - accuracy: 0.9399 - val_loss: 0.6167 - val_accuracy: 0.8675
# Epoch 4/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.1624 - accuracy: 0.9460
# Epoch 4: val_accuracy did not improve from 0.88065
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1623 - accuracy: 0.9460 - val_loss: 0.5294 - val_accuracy: 0.8801
# Epoch 5/100
# 5620/5625 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9506
# Epoch 5: val_accuracy did not improve from 0.88065
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1479 - accuracy: 0.9506 - val_loss: 0.8513 - val_accuracy: 0.8615
# Epoch 6/100
# 5619/5625 [============================>.] - ETA: 0s - loss: 0.1363 - accuracy: 0.9544
# Epoch 6: val_accuracy improved from 0.88065 to 0.90527, saving model to /content/checkpoint_entire_best.h5
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1363 - accuracy: 0.9544 - val_loss: 0.4066 - val_accuracy: 0.9053
# Epoch 7/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1294 - accuracy: 0.9560
# Epoch 7: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1294 - accuracy: 0.9560 - val_loss: 0.7582 - val_accuracy: 0.8767
# Epoch 8/100
# 5613/5625 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9580
# Epoch 8: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1234 - accuracy: 0.9580 - val_loss: 0.6997 - val_accuracy: 0.8798
# Epoch 9/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9599
# Epoch 9: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1179 - accuracy: 0.9600 - val_loss: 0.7077 - val_accuracy: 0.8810
# Epoch 10/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9607
# Epoch 10: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1142 - accuracy: 0.9608 - val_loss: 0.7259 - val_accuracy: 0.8798
# Epoch 11/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1121 - accuracy: 0.9612
# Epoch 11: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1120 - accuracy: 0.9612 - val_loss: 0.8640 - val_accuracy: 0.8730
# Epoch 12/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9626
# Epoch 12: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1090 - accuracy: 0.9626 - val_loss: 0.7744 - val_accuracy: 0.8844
# Epoch 13/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9644
# Epoch 13: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1048 - accuracy: 0.9644 - val_loss: 0.7568 - val_accuracy: 0.8865
# Epoch 14/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9640
# Epoch 14: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1057 - accuracy: 0.9640 - val_loss: 0.9080 - val_accuracy: 0.8846
# Epoch 15/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9647
# Epoch 15: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1035 - accuracy: 0.9647 - val_loss: 0.8913 - val_accuracy: 0.8785
# Epoch 16/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9656
# Epoch 16: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1023 - accuracy: 0.9656 - val_loss: 0.7830 - val_accuracy: 0.8862
# Epoch 17/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.0997 - accuracy: 0.9662
# Epoch 17: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0997 - accuracy: 0.9662 - val_loss: 0.8063 - val_accuracy: 0.8925
# Epoch 18/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1001 - accuracy: 0.9659
# Epoch 18: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1001 - accuracy: 0.9659 - val_loss: 1.0104 - val_accuracy: 0.8762
# Epoch 19/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.0989 - accuracy: 0.9665
# Epoch 19: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0990 - accuracy: 0.9664 - val_loss: 0.9336 - val_accuracy: 0.8784
# Epoch 20/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.0978 - accuracy: 0.9664
# Epoch 20: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0978 - accuracy: 0.9664 - val_loss: 1.0366 - val_accuracy: 0.8893
# Epoch 21/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.0965 - accuracy: 0.9671
# Epoch 21: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0965 - accuracy: 0.9671 - val_loss: 1.3237 - val_accuracy: 0.8697
# Epoch 22/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9672
# Epoch 22: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0956 - accuracy: 0.9671 - val_loss: 1.1079 - val_accuracy: 0.8849
# Epoch 23/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9676
# Epoch 23: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0954 - accuracy: 0.9676 - val_loss: 1.0906 - val_accuracy: 0.8837
# Epoch 24/100
# 5616/5625 [============================>.] - ETA: 0s - loss: 0.0942 - accuracy: 0.9679
# Epoch 24: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0943 - accuracy: 0.9679 - val_loss: 1.6896 - val_accuracy: 0.8696
# Epoch 25/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9675
# Epoch 25: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.0968 - accuracy: 0.9675 - val_loss: 1.1066 - val_accuracy: 0.8828
# Epoch 26/100
# 5620/5625 [============================>.] - ETA: 0s - loss: 0.0939 - accuracy: 0.9683
# Epoch 26: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0939 - accuracy: 0.9683 - val_loss: 1.1596 - val_accuracy: 0.8904
# Epoch 27/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9683
# Epoch 27: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.0926 - accuracy: 0.9683 - val_loss: 1.5921 - val_accuracy: 0.8727
# Epoch 28/100
# 5619/5625 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9680
# Epoch 28: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.0962 - accuracy: 0.9680 - val_loss: 1.3627 - val_accuracy: 0.8780
# Epoch 29/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9684
# Epoch 29: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.0954 - accuracy: 0.9684 - val_loss: 1.6408 - val_accuracy: 0.8788
# Epoch 30/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9686
# Epoch 30: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0936 - accuracy: 0.9687 - val_loss: 1.7170 - val_accuracy: 0.8783
# Epoch 31/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9689
# Epoch 31: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.0927 - accuracy: 0.9689 - val_loss: 1.2952 - val_accuracy: 0.8858
# Epoch 32/100
# 5616/5625 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9688
# Epoch 32: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0929 - accuracy: 0.9688 - val_loss: 1.4875 - val_accuracy: 0.8837
# Epoch 33/100
# 5616/5625 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9687
# Epoch 33: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0934 - accuracy: 0.9686 - val_loss: 1.7617 - val_accuracy: 0.8785
# Epoch 34/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.0975 - accuracy: 0.9682
# Epoch 34: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0975 - accuracy: 0.9682 - val_loss: 1.4187 - val_accuracy: 0.8870
# Epoch 35/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.0931 - accuracy: 0.9690
# Epoch 35: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0931 - accuracy: 0.9690 - val_loss: 1.5707 - val_accuracy: 0.8858
# Epoch 36/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9699
# Epoch 36: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0920 - accuracy: 0.9699 - val_loss: 1.4073 - val_accuracy: 0.8874
# Epoch 37/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9695
# Epoch 37: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0934 - accuracy: 0.9695 - val_loss: 1.5117 - val_accuracy: 0.8830
# Epoch 38/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.0938 - accuracy: 0.9695
# Epoch 38: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.0938 - accuracy: 0.9695 - val_loss: 1.8588 - val_accuracy: 0.8769
# Epoch 39/100
# 5620/5625 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9695
# Epoch 39: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0925 - accuracy: 0.9695 - val_loss: 1.5349 - val_accuracy: 0.8838
# Epoch 40/100
# 5622/5625 [============================>.] - ETA: 0s - loss: 0.0950 - accuracy: 0.9688
# Epoch 40: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0949 - accuracy: 0.9688 - val_loss: 1.6731 - val_accuracy: 0.8795
# Epoch 41/100
# 5613/5625 [============================>.] - ETA: 0s - loss: 0.0939 - accuracy: 0.9694
# Epoch 41: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0939 - accuracy: 0.9694 - val_loss: 1.7409 - val_accuracy: 0.8777
# Epoch 42/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.0946 - accuracy: 0.9694
# Epoch 42: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0946 - accuracy: 0.9694 - val_loss: 2.3127 - val_accuracy: 0.8694
# Epoch 43/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9693
# Epoch 43: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0953 - accuracy: 0.9693 - val_loss: 2.8208 - val_accuracy: 0.8650
# Epoch 44/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9698
# Epoch 44: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0956 - accuracy: 0.9698 - val_loss: 2.1904 - val_accuracy: 0.8760
# Epoch 45/100
# 5622/5625 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9698
# Epoch 45: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0944 - accuracy: 0.9698 - val_loss: 2.0008 - val_accuracy: 0.8794
# Epoch 46/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9693
# Epoch 46: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0943 - accuracy: 0.9693 - val_loss: 2.5008 - val_accuracy: 0.8763
# Epoch 47/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.9689
# Epoch 47: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0996 - accuracy: 0.9689 - val_loss: 1.6555 - val_accuracy: 0.8763
# Epoch 48/100
# 5613/5625 [============================>.] - ETA: 0s - loss: 0.1000 - accuracy: 0.9688
# Epoch 48: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0999 - accuracy: 0.9688 - val_loss: 1.7583 - val_accuracy: 0.8806
# Epoch 49/100
# 5622/5625 [============================>.] - ETA: 0s - loss: 0.0960 - accuracy: 0.9695
# Epoch 49: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0960 - accuracy: 0.9695 - val_loss: 1.8072 - val_accuracy: 0.8813
# Epoch 50/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9691
# Epoch 50: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1002 - accuracy: 0.9691 - val_loss: 1.8966 - val_accuracy: 0.8798
# Epoch 51/100
# 5619/5625 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9689
# Epoch 51: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.0987 - accuracy: 0.9689 - val_loss: 2.7103 - val_accuracy: 0.8612
# Epoch 52/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.9689
# Epoch 52: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1008 - accuracy: 0.9689 - val_loss: 2.2678 - val_accuracy: 0.8702
# Epoch 53/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9690
# Epoch 53: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.0995 - accuracy: 0.9690 - val_loss: 2.0452 - val_accuracy: 0.8761
# Epoch 54/100
# 5620/5625 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9683
# Epoch 54: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1010 - accuracy: 0.9683 - val_loss: 2.8352 - val_accuracy: 0.8696
# Epoch 55/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9692
# Epoch 55: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.0995 - accuracy: 0.9692 - val_loss: 3.9978 - val_accuracy: 0.8547
# Epoch 56/100
# 5616/5625 [============================>.] - ETA: 0s - loss: 0.1012 - accuracy: 0.9689
# Epoch 56: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1013 - accuracy: 0.9689 - val_loss: 2.3548 - val_accuracy: 0.8667
# Epoch 57/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9676
# Epoch 57: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1055 - accuracy: 0.9676 - val_loss: 2.7023 - val_accuracy: 0.8816
# Epoch 58/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9686
# Epoch 58: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1016 - accuracy: 0.9686 - val_loss: 3.5108 - val_accuracy: 0.8647
# Epoch 59/100
# 5616/5625 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9683
# Epoch 59: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1047 - accuracy: 0.9683 - val_loss: 3.0160 - val_accuracy: 0.8579
# Epoch 60/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9677
# Epoch 60: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1040 - accuracy: 0.9677 - val_loss: 2.0714 - val_accuracy: 0.8776
# Epoch 61/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9673
# Epoch 61: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1067 - accuracy: 0.9673 - val_loss: 2.4737 - val_accuracy: 0.8752
# Epoch 62/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1084 - accuracy: 0.9669
# Epoch 62: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1085 - accuracy: 0.9669 - val_loss: 3.5299 - val_accuracy: 0.8637
# Epoch 63/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9660
# Epoch 63: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.1134 - accuracy: 0.9660 - val_loss: 2.2856 - val_accuracy: 0.8663
# Epoch 64/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9667
# Epoch 64: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1108 - accuracy: 0.9666 - val_loss: 2.7714 - val_accuracy: 0.8648
# Epoch 65/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.1096 - accuracy: 0.9665
# Epoch 65: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1095 - accuracy: 0.9665 - val_loss: 2.4171 - val_accuracy: 0.8800
# Epoch 66/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9665
# Epoch 66: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1096 - accuracy: 0.9665 - val_loss: 2.7104 - val_accuracy: 0.8698
# Epoch 67/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1128 - accuracy: 0.9662
# Epoch 67: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1128 - accuracy: 0.9662 - val_loss: 4.7368 - val_accuracy: 0.8573
# Epoch 68/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9658
# Epoch 68: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.1180 - accuracy: 0.9657 - val_loss: 4.2014 - val_accuracy: 0.8675
# Epoch 69/100
# 5616/5625 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9661
# Epoch 69: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1169 - accuracy: 0.9661 - val_loss: 2.6398 - val_accuracy: 0.8745
# Epoch 70/100
# 5620/5625 [============================>.] - ETA: 0s - loss: 0.1127 - accuracy: 0.9666
# Epoch 70: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1127 - accuracy: 0.9666 - val_loss: 3.2733 - val_accuracy: 0.8713
# Epoch 71/100
# 5619/5625 [============================>.] - ETA: 0s - loss: 0.1159 - accuracy: 0.9661
# Epoch 71: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1160 - accuracy: 0.9661 - val_loss: 2.0649 - val_accuracy: 0.8673
# Epoch 72/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9648
# Epoch 72: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1209 - accuracy: 0.9648 - val_loss: 2.8230 - val_accuracy: 0.8830
# Epoch 73/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9657
# Epoch 73: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1180 - accuracy: 0.9657 - val_loss: 2.3175 - val_accuracy: 0.8828
# Epoch 74/100
# 5619/5625 [============================>.] - ETA: 0s - loss: 0.1217 - accuracy: 0.9646
# Epoch 74: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1217 - accuracy: 0.9646 - val_loss: 2.8809 - val_accuracy: 0.8565
# Epoch 75/100
# 5622/5625 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9651
# Epoch 75: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1200 - accuracy: 0.9652 - val_loss: 4.6498 - val_accuracy: 0.8690
# Epoch 76/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9641
# Epoch 76: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1250 - accuracy: 0.9641 - val_loss: 3.0809 - val_accuracy: 0.8640
# Epoch 77/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9646
# Epoch 77: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1224 - accuracy: 0.9646 - val_loss: 3.2163 - val_accuracy: 0.8789
# Epoch 78/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9634
# Epoch 78: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1248 - accuracy: 0.9635 - val_loss: 3.1808 - val_accuracy: 0.8819
# Epoch 79/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9641
# Epoch 79: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1269 - accuracy: 0.9641 - val_loss: 5.0834 - val_accuracy: 0.8693
# Epoch 80/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9642
# Epoch 80: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1252 - accuracy: 0.9642 - val_loss: 3.9431 - val_accuracy: 0.8748
# Epoch 81/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.9617
# Epoch 81: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1355 - accuracy: 0.9617 - val_loss: 4.6076 - val_accuracy: 0.8629
# Epoch 82/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9595
# Epoch 82: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1442 - accuracy: 0.9595 - val_loss: 2.7051 - val_accuracy: 0.8650
# Epoch 83/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9618
# Epoch 83: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1340 - accuracy: 0.9618 - val_loss: 5.7701 - val_accuracy: 0.8513
# Epoch 84/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9597
# Epoch 84: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1401 - accuracy: 0.9597 - val_loss: 6.1155 - val_accuracy: 0.8509
# Epoch 85/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9601
# Epoch 85: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1379 - accuracy: 0.9602 - val_loss: 4.7313 - val_accuracy: 0.8635
# Epoch 86/100
# 5612/5625 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9595
# Epoch 86: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1464 - accuracy: 0.9595 - val_loss: 5.9870 - val_accuracy: 0.8447
# Epoch 87/100
# 5625/5625 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9606
# Epoch 87: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 5ms/step - loss: 0.1380 - accuracy: 0.9606 - val_loss: 5.8950 - val_accuracy: 0.8591
# Epoch 88/100
# 5622/5625 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9597
# Epoch 88: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1390 - accuracy: 0.9597 - val_loss: 3.6506 - val_accuracy: 0.8532
# Epoch 89/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1527 - accuracy: 0.9573
# Epoch 89: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1527 - accuracy: 0.9573 - val_loss: 9.4124 - val_accuracy: 0.8562
# Epoch 90/100
# 5621/5625 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9573
# Epoch 90: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1579 - accuracy: 0.9573 - val_loss: 5.0763 - val_accuracy: 0.8485
# Epoch 91/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1514 - accuracy: 0.9576
# Epoch 91: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1515 - accuracy: 0.9576 - val_loss: 2.7501 - val_accuracy: 0.8763
# Epoch 92/100
# 5615/5625 [============================>.] - ETA: 0s - loss: 0.1491 - accuracy: 0.9572
# Epoch 92: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1490 - accuracy: 0.9572 - val_loss: 5.3837 - val_accuracy: 0.8654
# Epoch 93/100
# 5624/5625 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.9557
# Epoch 93: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1669 - accuracy: 0.9557 - val_loss: 1.6898 - val_accuracy: 0.8428
# Epoch 94/100
# 5614/5625 [============================>.] - ETA: 0s - loss: 0.1519 - accuracy: 0.9569
# Epoch 94: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1523 - accuracy: 0.9569 - val_loss: 4.9273 - val_accuracy: 0.8587
# Epoch 95/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9560
# Epoch 95: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1572 - accuracy: 0.9560 - val_loss: 8.5434 - val_accuracy: 0.8436
# Epoch 96/100
# 5618/5625 [============================>.] - ETA: 0s - loss: 0.1672 - accuracy: 0.9541
# Epoch 96: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1671 - accuracy: 0.9541 - val_loss: 11.3277 - val_accuracy: 0.8569
# Epoch 97/100
# 5613/5625 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.9540
# Epoch 97: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1675 - accuracy: 0.9540 - val_loss: 6.7550 - val_accuracy: 0.8533
# Epoch 98/100
# 5623/5625 [============================>.] - ETA: 0s - loss: 0.1683 - accuracy: 0.9547
# Epoch 98: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1683 - accuracy: 0.9547 - val_loss: 10.4468 - val_accuracy: 0.8475
# Epoch 99/100
# 5622/5625 [============================>.] - ETA: 0s - loss: 0.1745 - accuracy: 0.9524
# Epoch 99: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.1746 - accuracy: 0.9524 - val_loss: 9.3941 - val_accuracy: 0.8443
# Epoch 100/100
# 5617/5625 [============================>.] - ETA: 0s - loss: 0.1732 - accuracy: 0.9538
# Epoch 100: val_accuracy did not improve from 0.90527
# 5625/5625 [==============================] - 24s 4ms/step - loss: 0.1733 - accuracy: 0.9538 - val_loss: 5.6565 - val_accuracy: 0.8551

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team11'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team11'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 1250/1250 [==============================] - 3s 3ms/step - loss: 5.6565 - accuracy: 0.8551
# [5.656466007232666, 0.8550750017166138]
